# %% [markdown]
# # ✈️ 02 - Analyse des retards
#
# Exploration des causes de retard, des aéroports concernés, et premières visualisations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Affichage large
pd.set_option('display.max_columns', None)

# Charger les données
df = pd.read_csv("../data/flights_sample_3m.csv")

# %% [markdown]
# ## 🔍 Moyenne des retards par cause

# %%
delay_cols = [
    'DELAY_DUE_CARRIER',
    'DELAY_DUE_WEATHER',
    'DELAY_DUE_NAS',
    'DELAY_DUE_SECURITY',
    'DELAY_DUE_LATE_AIRCRAFT'
]

df[delay_cols].mean().sort_values(ascending=False).plot(kind='bar', title="Retard moyen par cause")
plt.ylabel("Minutes")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🛫 Top 10 aéroports de départ

# %%
df['ORIGIN'].value_counts().head(10).plot(kind='barh', title="Top 10 aéroports de départ")
plt.xlabel("Nombre de vols")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ❌ Répartition des vols annulés

# %%
df['CANCELLED'].value_counts(normalize=True).plot(kind='pie', labels=['Non annulé', 'Annulé'], autopct='%1.1f%%')
plt.title("Part des vols annulés")
plt.ylabel("")
plt.show()
